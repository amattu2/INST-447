# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/pga_outages_2019.csv");

# %%
df.head()
# Out:
#        autoEtor  ...   regionName
# 0           NaN  ...  Bakersfield
# 1           NaN  ...      Big sur
# 2           NaN  ...  Bridgeville
# 3  1.576676e+09  ...      Cambria
# 4           NaN  ...   Chowchilla
#
# [5 rows x 14 columns]

# %%
e = {"b": [1, 2], "c": [3, 4]}
e["b"]
# Out:
# [1, 2]

# %%
df["regionName"].value_counts()
# Out:
# San Jose         4
# Pleasanton       2
# Stockton         2
# Felton           2
# Mill Valley      2
# San Anselmo      2
# Bakersfield      1
# Vallejo          1
# Sebastopol       1
# Scotts Valley    1
# Scotia           1
# Santa Rosa       1
# Santa Cruz       1
# Rosedale         1
# Oakland          1
# Big sur          1
# Myers Flat       1
# Marysville       1
# Laytonville      1
# Grover Beach     1
# Escalon          1
# Elk              1
# Chowchilla       1
# Cambria          1
# Bridgeville      1
# Winton           1
# Name: regionName, dtype: int64

# %%
df["estCustAffected"].std()
# Out:
# 119.18072975867807
