# %%
import pandas as pd

import numpy as np

from pandas.io.json import json_normalize #special package in pandas

import json

data = [{'type':'DLSR','models':[{'name':'Nikon D850'},{'name':'Canon EOS'}]},
{'type':'Point-and-Shoot','models':[{'name':'Canon PowerShot'},{'name':'Nikon Coolpix'}]},
{'type':'Action','models':[{'name':'Go Pro Hero8'}]}]

# %%
df = json_normalize(data, record_path = 'models', meta = 'type')

df.head(200)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#               name             type
# 0       Nikon D850             DLSR
# 1        Canon EOS             DLSR
# 2  Canon PowerShot  Point-and-Shoot
# 3    Nikon Coolpix  Point-and-Shoot
# 4     Go Pro Hero8           Action

# %%
df.shape[0]
# Out:
# 5
