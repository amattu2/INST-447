# %% [markdown]
# # Lab 3 Data Basics
#
#
# Installations
# - Install Python 3
# - Install Jupyter Notebooks
# - Install modules you need, such as pandas and numpy

# %%
# import modules you need
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Part A: Python Review

# %%
# Create a string called string1 that contains your first and last name 
string1 = "Alec M"

# Print the string
print(string1)
# Out:
# Alec M

# %%
# Use list comprehension to divide each number in "mylist" by 2
mylist = [8,1,2,4,1,29]

for num in mylist:
  print(num / 2)
# Out:
# 4.0
# 0.5
# 1.0
# 2.0
# 0.5
# 14.5

# %%
# Create a dictionary to map names of the days of the week (e.g. Sunday, Monday, Tuesday)
# to numbers, where Sunday = 0, Monday = 1, Tuesday = 2, etc.
dayDict = {
  0: "Sun",
  1: "Mon",
  2: "Tue",
  3: "Wed",
  4: "Thu",
  5: "Fri",
  6: "Sat"
}

# Print the dictionary
print(dayDict)
# Out:
# {0: 'Sun', 1: 'Mon', 2: 'Tue', 3: 'Wed', 4: 'Thu', 5: 'Fri', 6: 'Sat'}

# %%
# Create a lambda function to multiply a number by 100. Name this function "mult_by_100"
mult_by_100 = lambda a: a * 100

# %%
# Use your lambda function, mult_by_100, to multiply the number 50 by 100
print(mult_by_100(50))
# Out:
# 5000

# %% [markdown]
# # Part B: Introduction Data Frames

# %% [markdown]
# ## Read in weather data

# %%
# read in the weather data from csv (WeatherData.csv)
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/WeatherData.csv");
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# print the first few rows of the weather data
df.head()
# Out:
#        STATION  ... WT09_ATTRIBUTES
# 0  USW00013743  ...             NaN
# 1  USW00013743  ...             NaN
# 2  USW00013743  ...             NaN
# 3  USW00013743  ...             NaN
# 4  USW00013743  ...             NaN
#
# [5 rows x 41 columns]

# %%
# print column and row dimensions for the weather data
df.shape
# Out:
# (90, 41)

# %%
# practice slicing weather data
# create a new data frame that has only the date (DATE) and the amount of precipitation (PRCP) columns
# make sure you save this slice to a new object (e.g. ndf)
ndf = df[["DATE", "PRCP"]]
ndf.head()
# Out:
#          DATE  PRCP
# 0  2017-01-01  0.00
# 1  2017-01-02  0.35
# 2  2017-01-03  0.86
# 3  2017-01-04  0.00
# 4  2017-01-05  0.00

# %%
# export the slice of your weather data frame with only date and precipitation (from the previous step) to a csv file called WeatherCols.csv
ndf.to_csv("WeatherCols.csv")

# %% [markdown]
# ## Read in trip data

# %%
# read in trip data (TripData.csv)
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/TripData.csv")

# %%
# print the first few rows of the trip data
df.head()
# Out:
#    Duration       Start date  ... Bike number  Member Type
# 0   1048876  3/31/2017 23:59  ...      W20784   Registered
# 1    223449  3/31/2017 23:59  ...      W20825   Registered
# 2    423494  3/31/2017 23:58  ...      W20773   Registered
# 3    687015  3/31/2017 23:57  ...      W01307   Registered
# 4    257919  3/31/2017 23:57  ...      W21760   Registered
#
# [5 rows x 9 columns]

# %%
# print the dimensions of the trip data
df.shape
# Out:
# (646508, 9)

# %%
# practice slicing the trip data
# create a new data frame with only the start date (Start date) and the duration (Duration) columns
dfn = df[["Start date", "Duration"]]
df.head()
# Out:
#    Duration       Start date  ... Bike number  Member Type
# 0   1048876  3/31/2017 23:59  ...      W20784   Registered
# 1    223449  3/31/2017 23:59  ...      W20825   Registered
# 2    423494  3/31/2017 23:58  ...      W20773   Registered
# 3    687015  3/31/2017 23:57  ...      W01307   Registered
# 4    257919  3/31/2017 23:57  ...      W21760   Registered
#
# [5 rows x 9 columns]

# %%
# write the new trip data frame with only the start date and duration to a csv file called TripsCol.csv
dfn.to_csv("TripsCol.csv")

# %% [markdown]
# ## Create day of the week data frame

# %%
# you can create a new data frame using dictionaries and lists
# create a dictionary with two keys "date" and "dayofweek"
# the date value should be a list of 7 dates from 2017-01-01 to 2017-01-07"
# the dayofweek value should a list of 7 days of the week starting with Sunday in order (e.g. Sunday, Monday, Tuesday ...)
# the dictionary should be of the format:
# mydict = {'colname1':['list','of','values','in','order'],'colname2':['list','of','values','same','order']}
mydict = {
  "date": [
    "2017-01-01",
    "2017-01-02",
    "2017-01-03",
    "2017-01-04",
    "2017-01-05",
    "2017-01-06",
    "2017-01-07"
  ],
  "dayofweek": [
    "Sunday",
    "Monday",
    "Tuesday",
    "Wednesday",
    "Thursday",
    "Friday",
    "Saturday",
  ]
}

# %%
# turn this dictionary into a data frame
df = pd.DataFrame(mydict)

# %%
# print the first few rows of the data frame
df.head()
# Out:
#          date  dayofweek
# 0  2017-01-01     Sunday
# 1  2017-01-02     Monday
# 2  2017-01-03    Tuesday
# 3  2017-01-04  Wednesday
# 4  2017-01-05   Thursday

# %%
# print the dimensions of the data frame
df.shape
# Out:
# (7, 2)

# %%
# write this data frame to csv file
df.to_csv("WeekDay.csv")

# %% [markdown]
# # Part C: Summarizing Data

# %% [markdown]
# ## Summarize weather data (from Part B)

# %%
# get the frequency distribution for the name column (NAME) using the value_counts method
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/WeatherData.csv");

df["NAME"].value_counts()
# Out:
# WASHINGTON REAGAN NATIONAL AIRPORT, VA US    90
# Name: NAME, dtype: int64

# %%
# get descriptive statistics for all numeric columns in the weather data set
df.describe()
# Out:
#             AWND       PRCP       SNOW  ...  WT08  WT09  WT09_ATTRIBUTES
# count  90.000000  90.000000  90.000000  ...   5.0   0.0              0.0
# mean   10.165111   0.073556   0.037778  ...   1.0   NaN              NaN
# std     4.222339   0.190046   0.185168  ...   0.0   NaN              NaN
# min     3.580000   0.000000   0.000000  ...   1.0   NaN              NaN
# 25%     6.765000   0.000000   0.000000  ...   1.0   NaN              NaN
# 50%     9.510000   0.000000   0.000000  ...   1.0   NaN              NaN
# 75%    12.472500   0.020000   0.000000  ...   1.0   NaN              NaN
# max    21.920000   0.960000   1.100000  ...   1.0   NaN              NaN
#
# [8 rows x 21 columns]

# %%
# get the sum of "total precipitation" (PRCP) using the sum function
df.PRCP.sum()
# Out:
# 6.62

# %% [markdown]
# ## Summarize trip/rideshare data (from Part B)

# %%
# get frequency distribution for "Start station" using the value_counts method
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/TripData.csv")

df["Start station"].value_counts()
# Out:
# Columbus Circle / Union Station         13712
# Massachusetts Ave & Dupont Circle NW     9071
# 15th & P St NW                           8195
# Jefferson Dr & 14th St SW                8026
# Lincoln Memorial                         7876
#                                         ...
# Taft St & E Gude Dr                         9
# Traville Gateway Dr & Gudelsky Dr           7
# Broschart & Blackwell Rd                    3
# Deanwood Rec Center                         3
# Reston Regional Library                     3
# Name: Start station, Length: 452, dtype: int64

# %%
# get descriptive statistics for all numeric columns in the trip/rideshare data set
df.describe()
# Out:
#            Duration  Start station number  End station number
# count  6.465080e+05         646508.000000       646508.000000
# mean   1.010939e+06          31317.412205        31320.159981
# std    2.087019e+06            218.034575          216.394488
# min    6.000400e+04          31000.000000        31000.000000
# 25%    3.732280e+05          31202.000000        31207.000000
# 50%    6.263670e+05          31251.000000        31250.000000
# 75%    1.064398e+06          31505.000000        31505.000000
# max    8.606654e+07          32223.000000        32223.000000

# %%
# get the mode of "End station" using the mode method
df.mode()["End station"]
# Out:
# 0    Columbus Circle / Union Station
# 1                                NaN
# Name: End station, dtype: object

# %% [markdown]
# # Part D: Visualizing Data

# %%
# import module for plotting & use jupyter magic to display pictures in cells
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read in the combined weather and trip data (WeatherTrips.csv)
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/WeatherTrips.csv")

# %% [markdown]
# ## Create histograms for each numeric variable. Each histogram must have axis labels AND a title

# %%
# histogram of number of trips (NumTrips)
plt.hist(df.NumTrips)
plt.title("Histogram of Trips")
plt.ylabel("Frequency")
plt.xlabel("Distribution")

None; # Hide debug output

# %%
# histogram of precipitation (PRCP)
plt.hist(df.PRCP)
plt.title("Histogram of Precipitation")
plt.ylabel("Count")
plt.xlabel("Distribution")

None; # Hide debug output

# %%
# histogram of average temperature (TAVG)
plt.hist(df.TAVG)
plt.title("Histogram of Temperature Average")
plt.ylabel("Count")
plt.xlabel("Distribution")

None; # Hide debug output

# %%
# histogram of wind speed (AWND)
plt.hist(df.AWND)
plt.title("Histogram of Wind Speed")
plt.ylabel("Frequency")
plt.xlabel("Distribution")

None; # Hide debug output

# %% [markdown]
# ## Create barcharts that display each numeric variable over time

# %%
# Do NOT DELETE -- these options will make your chart easier to read!
plt.figure(figsize=(30,5))
plt.xticks(rotation=90)

# barchart of date (DATE) vs number of trips (NumTrips)
plt.bar(df.DATE, df.NumTrips)

None; # Hide debug output

# %%
# Do NOT DELETE -- these options will make your chart easier to read!
plt.figure(figsize=(30,5))
plt.xticks(rotation=90)

# barchart of date (DATE) vs precipitation (PRCP)
plt.bar(df.DATE, df.PRCP)

None; # Hide debug output

# %%
# Do NOT DELETE -- these options will make your chart easier to read!
plt.figure(figsize=(30,5))
plt.xticks(rotation=90)

# barchart of date (DATE) vs average temparature (TAVG)
plt.bar(df.DATE, df.TAVG)

None; # Hide debug output

# %%
# Do NOT DELETE -- these options will make your chart easier to read!
plt.figure(figsize=(30,5))
plt.xticks(rotation=90)

# barchart of date (DATE) vs wind speed (AWND)
plt.bar(df.DATE, df.AWND)

None; # Hide debug output

# %% [markdown]
# ## Create scatterplots of each numeric variable with number of trips

# %%
# scatterplot of precipitation (PRCP) vs number of trips (NumTrips)
plt.scatter(df.PRCP, df.NumTrips)

None; # Hide output

# %%
# scatterplot of average temperature (TAVG) vs number of trips (NumTrips)
plt.scatter(df.TAVG, df.NumTrips)

None; # Hide output

# %%
# scatterplot of average wind speed (AWND) vs number of trips (NumTrips)
plt.scatter(df.AWND, df.NumTrips)

None; # Hide output
