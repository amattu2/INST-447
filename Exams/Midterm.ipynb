# %% [markdown]
# # Midterm Exam
# ## INST 447
# ## Spring '22
# ## Alec M.

# %%
# Import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import sqlite3
from google.colab import drive
from pandas.io.json import json_normalize #special package in pandas
from lxml import etree

# %%
# Mount Storage (colab.research.google.com)
drive.mount('/content/drive', force_remount = False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import Data
cases_covid19 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/INST 447/cases_coronavirus.csv")

covid19 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/INST 447/covid19.csv")

dewiki = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/INST 447/dewiki_pageviews.csv")

enwiki = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/INST 447/enwiki_pageviews.csv")

nobel = []
with open("/content/drive/MyDrive/Colab Notebooks/INST 447/nobel_prizes.json") as f:
  nobel = json.load(f)
  nobel_df = json_normalize(nobel)

tweets = []
with open("/content/drive/MyDrive/Colab Notebooks/INST 447/tweets.json") as f:
  tweets = json.load(f)
  tweets_df = json_normalize(tweets)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
cases_covid19.head()
# Out:
#       Date  US  Germany
# 0  1/21/20   1      NaN
# 1  1/22/20   1      NaN
# 2  1/23/20   1      NaN
# 3  1/24/20   2      NaN
# 4  1/25/20   2      NaN

# %%
covid19.head()
# Out:
#    id reporting date                                            summary  \
# 0   1        1/20/20  First confirmed imported COVID-19 pneumonia pa...
# 1   2        1/20/20  First confirmed imported COVID-19 pneumonia pa...
# 2   3        1/21/20  First confirmed imported cases in Zhejiang: pa...
# 3   4        1/21/20  new confirmed imported COVID-19 pneumonia in T...
# 4   5        1/21/20  new confirmed imported COVID-19 pneumonia in T...
#
#               location country  gender   age symptom_onset  \
# 0  Shenzhen, Guangdong   China    male  66.0        1/3/20
# 1             Shanghai   China  female  56.0       1/15/20
# 2             Zhejiang   China    male  46.0        1/4/20
# 3              Tianjin   China  female  60.0           NaN
# 4              Tianjin   China    male  58.0           NaN
#
#    If_onset_approximated hosp_visit_date exposure_start exposure_end  \
# 0                    0.0         1/11/20       12/29/19       1/4/20
# ...

# %%
dewiki.head()
# Out:
#       Date  Coronavirus  NovelCoronavirus
# 0  1/14/20          720                 0
# 1  1/15/20          479                 0
# 2  1/16/20         1922                 0
# 3  1/17/20         5781                 0
# 4  1/18/20         5538                 0

# %%
enwiki.head()
# Out:
#       Date  Coronavirus  NovelCoronavirus
# 0  1/14/20         4991                 0
# 1  1/15/20         4203                 0
# 2  1/16/20        11822                 0
# 3  1/17/20        15099                 0
# 4  1/18/20        28342                 0

# %%
nobel_df.head()
# Out:
#    year    category                                          laureates  \
# 0  2019   chemistry  [{'id': '976', 'firstname': 'John', 'surname':...
# 1  2019   economics  [{'id': '982', 'firstname': 'Abhijit', 'surnam...
# 2  2019  literature  [{'id': '980', 'firstname': 'Peter', 'surname'...
# 3  2019       peace  [{'id': '981', 'firstname': 'Abiy', 'surname':...
# 4  2019     physics  [{'id': '973', 'firstname': 'James', 'surname'...
#
#                                    overallMotivation
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  "for contributions to our understanding of the...

# %%
tweets_df
# Out:
#                        created_at                   id               id_str  \
# 0  Sun Aug 09 13:21:10 +0000 2020  1292450854042308609  1292450854042308609
#
#                                                 text  \
# 0  Was up at 0430 yesterday just to sit around un...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...       True
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ...  \
# 0                    None  ...
#
#                             extended_tweet.full_text  \
# 0  Was up at 0430 yesterday just to sit around un...
#
#   extended_tweet.display_text_range extended_tweet.entities.hashtags  \
# 0                          [0, 178]                               []
#
#   extended_tweet.entities.urls  extended_tweet.entities.user_mentions  \
# ...

# %%
# Average COVID-19 Case Age of Males
C19_males = covid19.loc[covid19['gender'] == 'male']

# C19_males.head()
C19_males.describe()
# Out:
#                 id         age  If_onset_approximated  visiting Wuhan  \
# count   520.000000  476.000000             339.000000      520.000000
# mean    470.953846   49.847689               0.041298        0.198077
# std     305.781777   17.888556               0.199273        0.398934
# min       1.000000    0.500000               0.000000        0.000000
# 25%     213.750000   36.000000               0.000000        0.000000
# 50%     429.500000   50.500000               0.000000        0.000000
# 75%     732.250000   65.000000               0.000000        0.000000
# max    1085.000000   89.000000               1.000000        1.000000
#
#        from Wuhan       death   recovered
# count  518.000000  520.000000  520.000000
# mean     0.158301    0.084615    0.007692
# std      0.365376    0.278576    0.087452
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000
# ...

# %%
covid19.groupby(["country"]).count()
# Out:
#               id  reporting date  summary  location  gender  age  \
# country
# Afghanistan    1               1        1         1       0    1
# Algeria        1               1        1         1       1    0
# Australia     15              15       15        15      15   15
# Austria        2               2        2         2       0    2
# Bahrain       17              17       17        17      15    0
# Belgium        1               1        1         1       0    0
# Cambodia       1               1        1         1       1    1
# Canada        12              12       12        12      12   12
# China        197             197      193       197     197  190
# Croatia        1               1        1         1       1    0
# Egypt          1               1        1         1       0    0
# Finland        1               1        1         1       1    1
# France        39              39       39        39      20   18
# ...

# %%
# WikiPedia 
# dewiki = Germany
dewiki["GermanPageviews"] = dewiki[["Coronavirus", "NovelCoronavirus"]].apply(lambda x: sum(x), 1)

dewiki.head()
# Out:
#       Date  Coronavirus  NovelCoronavirus  GermanPageviews
# 0  1/14/20          720                 0              720
# 1  1/15/20          479                 0              479
# 2  1/16/20         1922                 0             1922
# 3  1/17/20         5781                 0             5781
# 4  1/18/20         5538                 0             5538

# %%
dewiki.head(25)
# Out:
#        Date  Coronavirus  NovelCoronavirus  GermanPageviews
# 0   1/14/20          720                 0              720
# 1   1/15/20          479                 0              479
# 2   1/16/20         1922                 0             1922
# 3   1/17/20         5781                 0             5781
# 4   1/18/20         5538                 0             5538
# 5   1/19/20         9863                 0             9863
# 6   1/20/20        38368                 0            38368
# 7   1/21/20        47690                 0            47690
# 8   1/22/20        65338                 0            65338
# 9   1/23/20        74092                 0            74092
# 10  1/24/20       144055                 0           144055
# 11  1/25/20       154598              1901           156499
# 12  1/26/20       137454             25255           162709
# 13  1/27/20       115875             35954           151829
# 14  1/28/20       290130             56280           346410
# ...

# %%
dewiki.max()
# Out:
# Date                2/3/20
# Coronavirus         290130
# NovelCoronavirus     56280
# GermanPageviews     346410
# dtype: object

# %%
# Join DE and EN
wiki = pd.merge(enwiki, dewiki, how = 'inner', on = ['Date'])

print(dewiki.shape)
print(enwiki.shape)
print(wiki.shape)

wiki.head()
# Out:
# (21, 4)
# (21, 3)
# (21, 6)
#       Date  Coronavirus_x  NovelCoronavirus_x  Coronavirus_y  \
# 0  1/14/20           4991                   0            720
# 1  1/15/20           4203                   0            479
# 2  1/16/20          11822                   0           1922
# 3  1/17/20          15099                   0           5781
# 4  1/18/20          28342                   0           5538
#
#    NovelCoronavirus_y  GermanPageviews
# 0                   0              720
# 1                   0              479
# 2                   0             1922
# 3                   0             5781
# 4                   0             5538

# %%
tweets['id']
# Out:
# 1292450854042308609

# %%
user_df = json_normalize(tweets['user'])

user_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#           id     id_str    name  screen_name    location   url    description  \
# 0  624248526  624248526  Azalia  a_degollado  Texas, USA  None  21 • TXARNG •
#
#   translator_type  protected  verified  ...  profile_text_color  \
# 0            none      False     False  ...              3D1957
#
#    profile_use_background_image  \
# 0                          True
#
#                                    profile_image_url  \
# 0  http://pbs.twimg.com/profile_images/1287596857...
#
#                              profile_image_url_https  \
# 0  https://pbs.twimg.com/profile_images/128759685...
#
#                                   profile_banner_url default_profile  \
# 0  https://pbs.twimg.com/profile_banners/62424852...           False
#
# ...

# %%
user_df['screen_name']
# Out:
# 0    a_degollado
# Name: screen_name, dtype: object

# %%
user_df['location']
# Out:
# 0    Texas, USA
# Name: location, dtype: object

# %%
nobel[0]
# Out:
# {'category': 'chemistry',
#  'laureates': [{'firstname': 'John',
#    'id': '976',
#    'motivation': '"for the development of lithium-ion batteries"',
#    'share': '3',
#    'surname': 'Goodenough'},
#   {'firstname': 'M. Stanley',
#    'id': '977',
#    'motivation': '"for the development of lithium-ion batteries"',
#    'share': '3',
#    'surname': 'Whittingham'},
#   {'firstname': 'Akira',
#    'id': '978',
#    'motivation': '"for the development of lithium-ion batteries"',
#    'share': '3',
#    'surname': 'Yoshino'}],
#  'year': '2019'}

# %%
type(nobel)
# Out:
# list

# %%
prizes = json_normalize(nobel, record_path="laureates", meta=["year","category"])

prizes.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#     id   firstname      surname  \
# 0  976        John   Goodenough
# 1  977  M. Stanley  Whittingham
# 2  978       Akira      Yoshino
# 3  982     Abhijit     Banerjee
# 4  983      Esther        Duflo
#
#                                           motivation share  year   category
# 0     "for the development of lithium-ion batteries"     3  2019  chemistry
# 1     "for the development of lithium-ion batteries"     3  2019  chemistry
# 2     "for the development of lithium-ion batteries"     3  2019  chemistry
# 3  "for their experimental approach to alleviatin...     3  2019  economics
# 4  "for their experimental approach to alleviatin...     3  2019  economics

# %%
prizes.groupby(["category"]).count()
# Out:
#              id  firstname  surname  motivation  share  year
# category
# chemistry    98         98       98          98     98    98
# economics    75         75       75          75     75    75
# literature   45         45       45          45     45    45
# medicine    106        106      106         106    106   106
# peace        63         63       47          63     63    63
# physics     112        112      112         112    112   112

# %%
prizes[["year","category","id"]].groupby(["year","category"]).agg("count")
# Out:
#                  id
# year category
# 1975 chemistry    2
#      economics    2
#      literature   1
#      medicine     3
#      peace        1
# ...              ..
# 2019 economics    3
#      literature   1
#      medicine     3
#      peace        1
#      physics      3
#
# [270 rows x 1 columns]
